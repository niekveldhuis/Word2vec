# %% [markdown]
# # Some basic statistics on the Akkadian ORACC corpus

# %%
import glob
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Load the data

# %%
path =r'output' # indicate the local path where files are stored
allFiles = glob.glob(path + "/*.csv")
list_ = []
files_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    df['id_text'] = [file_[7:-4].replace('_', '/') + '/' + text for text in df['id_text']]
    df['lemma'] = [lemma.replace('$', '') for lemma in df['lemma']]
    list_.append(df)
    files_.append(file_[7:-4].replace('_', '/'))
data = pd.concat(list_).reset_index(drop=True)

# %% [markdown]
# # How many texts are included?

# %%
data.shape
# Out:
# (7071, 2)

# %%
length = [text[:5] for text in data['lemma']]
length
# Out:
# ['ana[t',
#  'ana[t',
#  'x[NA]',
#  'x[NA]',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'umma[',
#  'ana[t',
#  'umma[',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ṭuppu',
#  'ana[t',
#  'šanīt',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'šanīt',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'šâlu[',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'umma[',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'Rib-H',
#  'šanīt',
#  'x[NA]',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x-ka[',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'amāru',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  '7-šu[',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'Rib-H',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'ṭuppu',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'annû[',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'šarru',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'abu[f',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x-in[',
#  'x[NA]',
#  'x-ia[',
#  'ana[t',
#  'u[and',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'u[and',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'n[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'itti[',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'ana[t',
#  'n[NA]',
#  'ana[t',
#  'ana[t',
#  'Rib-H',
#  'Rib-H',
#  'x-u₂[',
#  'x[NA]',
#  'x[NA]',
#  'ana[t',
#  'nâdu[',
#  'rīmu[',
#  'aššu[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'bēlu[',
#  'ana[t',
#  'x[NA]',
#  'nu[NA',
#  'x[NA]',
#  'arnu[',
#  'x[NA]',
#  'ša[th',
#  'x[NA]',
#  'ina[i',
#  'x[NA]',
#  'ṭupša',
#  'bārû[',
#  'x-x-š',
#  'x[NA]',
#  'x-li-',
#  'x[NA]',
#  'māmīt',
#  'x[NA]',
#  'ana[t',
#  'lā[no',
#  'kabtu',
#  'x-x[N',
#  'kīma[',
#  'Ninur',
#  'gaṣṣu',
#  'lītu[',
#  'x-x[N',
#  'x-ka[',
#  'ina[i',
#  'x[NA]',
#  'utukk',
#  'bēlu[',
#  'qû[fl',
#  'ṭupša',
#  'Lugal',
#  'x[NA]',
#  'ana[t',
#  'ilu[g',
#  'li[NA',
#  'bēlu[',
#  'x[NA]',
#  'uṣurt',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'purus',
#  'ana[t',
#  'x[NA]',
#  'x-x-k',
#  'kīma[',
#  'taqri',
#  'šatû[',
#  'x[NA]',
#  'x[NA]',
#  'MIN[N',
#  'x[NA]',
#  'ṭupša',
#  'x[NA]',
#  'sakku',
#  'x[NA]',
#  'hīpu[',
#  'ina[i',
#  'x[NA]',
#  'x[NA]',
#  'x-ti[',
#  'x[NA]',
#  'x[NA]',
#  'giṭṭu',
#  'x[NA]',
#  'x[NA]',
#  'ṭupša',
#  'x[NA]',
#  'Anu[1',
#  'x-x[N',
#  'ūṣu[a',
#  'ša[th',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ṭupša',
#  'x[NA]',
#  'x[NA]',
#  'u₂[NA',
#  'x[NA]',
#  'ēkall',
#  'x[NA]',
#  'x[NA]',
#  'el-pe',
#  'inūma',
#  'ana[t',
#  'x[NA]',
#  'x[NA]',
#  'barû[',
#  'x[NA]',
#  'ana[t',
#  'mu-na',
#  'x[NA]',
#  'x[NA]',
#  'ša[of',
#  'ana[t',
#  'ni-ṭi',
#  'adi[u',
#  'x[NA]',
#  'x[NA]',
#  'ina[i',
#  'pu-lu',
#  'x[NA]',
#  'x-x[N',
#  'x[NA]',
#  'qarrā',
#  'x[NA]',
#  'x[NA]',
#  'anāku',
#  'a-HUR',
#  'ša[of',
#  'hi-pi',
#  'anāku',
#  'x-ia[',
#  'māmīt',
#  'nāšû[',
#  'anāku',
#  'x[NA]',
#  'x-x[N',
#  'qinnā',
#  'ša[th',
#  'x[NA]',
#  'māmīt',
#  'x[NA]',
#  'ašru[',
#  'kīma[',
#  'ša[th',
#  'anāku',
#  'libbu',
#  'x-šu₂',
#  'x[NA]',
#  'x[NA]',
#  'māmīt',
#  'libbu',
#  'x[NA]',
#  'anāku',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x-x-t',
#  'adi[u',
#  'bēlu[',
#  'x[NA]',
#  'x-um-',
#  'x[NA]',
#  'x[NA]',
#  'qinna',
#  'x[NA]',
#  'qātu[',
#  'mubal',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ina[i',
#  'qarrā',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'bēltu',
#  'x[NA]',
#  'kīma[',
#  'x[NA]',
#  'kīma[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'kīma[',
#  'x[NA]',
#  'x[NA]',
#  'ištar',
#  'qātu[',
#  'ki-x[',
#  'x[NA]',
#  'x-UG[',
#  'x-mu-',
#  'x-x[N',
#  'na-ak',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'qātu[',
#  'māmīt',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x-x[N',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'bītu[',
#  'mamma',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ni-hi',
#  'ina[N',
#  'ina[N',
#  'ina[N',
#  'lit-t',
#  'bi-tu',
#  'x-ti[',
#  'ina[N',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'lišān',
#  'kišād',
#  'taqri',
#  'anāku',
#  'x[NA]',
#  'bēlu[',
#  'ša₂[N',
#  'x[NA]',
#  'ina[N',
#  'ina[N',
#  'ina[N',
#  'šin-n',
#  'ina[N',
#  'x[NA]',
#  'ša₂[N',
#  'x[NA]',
#  'lib-b',
#  'ina[N',
#  'x-x[N',
#  'a-pu[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ba-aš',
#  'x-lu₄',
#  'x-x-l',
#  'ina[N',
#  'qar-r',
#  'ina[N',
#  'x[NA]',
#  'x[NA]',
#  'ri-mu',
#  'ina[i',
#  'ana[N',
#  'IŠ-x[',
#  'u₂-tu',
#  'x[NA]',
#  'ni-is',
#  'a-hu-',
#  'e[NA]',
#  'aš₂-a',
#  'a-hu-',
#  'na-as',
#  'eṭ-lu',
#  'x[NA]',
#  'ša₂[N',
#  'ina[N',
#  'x[NA]',
#  'ru-ba',
#  'U[NA]',
#  'ina[N',
#  'ina[N',
#  'x[NA]',
#  'x[NA]',
#  'x-x[N',
#  'ina[N',
#  'man-n',
#  'x[NA]',
#  'x[NA]',
#  'aš-šu',
#  'ku-ša',
#  'x-x-š',
#  'x[NA]',
#  'x-x[N',
#  'x-ri[',
#  'x[NA]',
#  'ina[N',
#  'E₂-i-',
#  'x[NA]',
#  'x[NA]',
#  'šub-t',
#  'x[NA]',
#  'x[NA]',
#  'ina[N',
#  'ina[N',
#  'x[NA]',
#  'RI[NA',
#  'x[NA]',
#  'epušt',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'hīṭu[',
#  'qātu[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ina[i',
#  'x[NA]',
#  'x-ti[',
#  'arnu[',
#  'anāku',
#  'x[NA]',
#  'bēltu',
#  'x-kun',
#  'x[NA]',
#  'kabat',
#  'ina[i',
#  'ina[i',
#  'x[NA]',
#  'x[NA]',
#  'rigmu',
#  'x[NA]',
#  'ina[i',
#  'māmīt',
#  'rubāt',
#  'māmīt',
#  'x[NA]',
#  'ša[th',
#  'ṭupša',
#  'ana[t',
#  'ašru[',
#  'x[NA]',
#  'x[NA]',
#  'māmīt',
#  'gappu',
#  'daltu',
#  'x[NA]',
#  'ana[t',
#  'x[NA]',
#  'uṣurt',
#  'ša[th',
#  'x[NA]',
#  'ša[th',
#  'qû[fl',
#  'ša[of',
#  'lā[no',
#  'rubû[',
#  'bīnu[',
#  'barāq',
#  'x[NA]',
#  'ūmu[d',
#  'ina[i',
#  'ina[i',
#  'mimmû',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'apput',
#  'šabal',
#  'x[NA]',
#  'ina[i',
#  'ina[i',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ana[t',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'Asare',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'šarru',
#  'x[NA]',
#  'x[NA]',
#  'barāq',
#  'šarāh',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'enēnu',
#  'šattu',
#  'eṭlu[',
#  'x[NA]',
#  'ana[t',
#  'x[NA]',
#  'ana[t',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'Adad-',
#  '24[NA',
#  'ana[t',
#  'šiptu',
#  'šiptu',
#  'šiptu',
#  'šiptu',
#  'nambu',
#  'šiptu',
#  'šiptu',
#  'ana[t',
#  'šiptu',
#  'šiptu',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'asakk',
#  'Namta',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ṭīdu[',
#  'šumma',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'šiptu',
#  'awīlu',
#  'x[NA]',
#  'ana[t',
#  'šiptu',
#  'awīlu',
#  'x[NA]',
#  'x[NA]',
#  'awīlu',
#  'x[NA]',
#  '1/2[N',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ina[i',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  '1[NA]',
#  'arabā',
#  'x[NA]',
#  'ina[i',
#  'x[NA]',
#  'muppi',
#  'šamnu',
#  'x[NA]',
#  'x[NA]',
#  '1[NA]',
#  '1[NA]',
#  'x[NA]',
#  'šaṭār',
#  'x[NA]',
#  'x[NA]',
#  'Addar',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x-x-{',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  '{m}ri',
#  '{m}{d',
#  '{m}x[',
#  '{m}x[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'Ina-q',
#  'mukin',
#  'warād',
#  'x[NA]',
#  'x[NA]',
#  'A[NA]',
#  'nambu',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'dāmu[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'marṣu',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ūmu[d',
#  'marṣu',
#  'x[NA]',
#  'sinni',
#  'x[NA]',
#  'x[NA]',
#  'ištu[',
#  'awīlu',
#  'x[NA]',
#  'awīlu',
#  'awīlu',
#  'awīlu',
#  'x[NA]',
#  'kalma',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'gamlu',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'anzah',
#  'x[NA]',
#  'kukur',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'šumma',
#  'x[NA]',
#  'bītu[',
#  'x[NA]',
#  'x[NA]',
#  'awīlu',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'ina[i',
#  'x[NA]',
#  'bibbu',
#  'x[NA]',
#  'šumma',
#  'x[NA]',
#  'Agru[',
#  'Nisan',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  '10[NA',
#  'x[NA]',
#  'Sin[1',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x-SU[',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'māmīt',
#  'x[NA]',
#  'ina[i',
#  'x[NA]',
#  'ana[t',
#  'AD[NA',
#  'x[NA]',
#  'kapāṣ',
#  'ina[i',
#  'šiptu',
#  'šiptu',
#  'x[NA]',
#  'x[NA]',
#  'erēbu',
#  'ina[i',
#  'awīlu',
#  'Mardu',
#  'x[NA]',
#  'šarru',
#  'šumma',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'x[NA]',
#  'warhu',
#  'ūmu[d',
#  'x[NA]',
#  'šumma',
#  'x-ma[',
#  'x[NA]',
#  'x[NA]',
#  'uqnû[',
#  'ṭuppu',
#  '2[NA]',
#  '55[NA',
#  'Humba',
#  'diʾu[',
#  'māmīt',
#  'x[NA]',
#  'x[NA]',
#  'šiptu',
#  'šiptu',
#  'x[NA]',
#  'nambu',
#  'iṣṣūr',
#  'x[NA]',
#  'inūma',
#  'x[NA]',
#  'x[NA]',
#  'šumma',
#  ...]

# %%
length = [len(data['lemma'][i].split()) for i in range(len(data['lemma']))]
np.mean(length)
# Out:
# 0    946584
# dtype: int64

# %%
cv = CountVectorizer(analyzer='word', token_pattern=r'[^ ]+')
fit = cv.fit_transform(data['lemma'])
dtm = pd.DataFrame(fit.toarray(), columns = cv.get_feature_names(), index = data['id_text'])

# %% [markdown]
# # Keep lemmatized words only

# %%
words = [word for word in dtm.columns if not word.endswith('[na]na')]
dtm = dtm[words]
dtm.shape
# Out:
# (7071, 21587)

# %%
terms = ['immeru[sheep]n', 'puhādu[lamb]n', 'arhu[cow]n', 'būru[(bull)-calf]n']
dtm[terms].sum()
# Out:
# immeru[sheep]n        435
# puhādu[lamb]n          40
# arhu[cow]n             18
# būru[(bull)-calf]n     14
# dtype: int64

# %%
dtm.sum().sort_values(ascending=False)
# Out:
# ina[in]prp                              25434
# ana[to]prp                              24914
# ša[of]det                               24424
# šarru[king]n                            18566
# u[and]cnj                               16753
# māru[son]n                              16188
# bēlu[lord]n                             12900
# ša[that]rel                             11070
# ūmu[day]n                                8007
# lā[not]mod                               6906
# bītu[house]n                             6662
# mātu[land]n                              5733
# libbu[interior]n                         4993
# ilu[god]n                                4282
# šību[witness]n                           4035
# alāku[go]v                               3971
# pānu[front]n                             3607
# muhhu[skull]n                            3577
# unqu[ring]n                              3516
# epēšu[do]v                               3384
# ištu[from]prp                            3256
# šuāti[him]ip                             3202
# lū[may]mod                               3163
# šakānu[put]v                             2906
# qabû[say]v                               2786
# adi[until]prp                            2706
# mā[saying]prp                            2618
# qātu[hand]n                              2606
# šapāru[send]v                            2584
# ālu[city]n                               2577
#                                         ...
# mušabšû[that-calls-into-existence]n         1
# mušabšiʾu-sibitti[eponym]pn                 1
# muzīqātu[(a-disease?)]n                     1
# muzzazu[standing]n                          1
# muzibbu[letting-flow]n                      1
# muzaʾʾiztu[distributer]n                    1
# mušalsû[one-who-makes-shout]n               1
# mušamdilu[who-makes-something-wide]n        1
# mušamhiru[one-who-makes-receive]n           1
# mušammihu[who-makes-flourish]n              1
# mušazninu[one-who-makes-rain]n              1
# mušattiru[one-who-demolishes]n              1
# mušatbû[one-who-raises-up]n                 1
# mušatbatu[one-who-raises]n                  1
# mušarriṭu[that-tears-(garments)]n           1
# mušarrihu[splendid-one]n                    1
# mušarrihu[one-who-takes-pride-in]n          1
# mušardû[leaking]aj                          1
# mušarbibu[one-who-submits]n                 1
# mušaqqiltu[scales]n                         1
# mušapširu[one-who-dispels]n                 1
# mušapšihu[who-pacifies]n                    1
# mušaprisu[one-who-blocks]n                  1
# mušappiku[one-who-heaps-up]n                1
# mušanwiru[one-who-caouse-to-bright]n        1
# mušannû[meaning-unknown]n                   1
# mušamriṣtu[one-who-causes-sickness]n        1
# mušamqitu[overturning]aj                    1
# mušamqitu[one-who-brings-to-fall]n          1
# a-eridu[1]dn                                1
# dtype: int64
