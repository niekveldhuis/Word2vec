# %% [markdown]
# # Importing ORACC Data from corpus.json
# by Niek Veldhuis
# UC Berkeley
#
# February 2017
#
# # TODO
# * check that COFs are treated properly
# * check that lines that continue into the next line (as in bilinguals) are captured completely.
#
#
# # Introduction
#
# Purpose of the code is to download [ORACC](http://oracc.org) JSON files that contain textual data and produce a `.csv` file with the relevant data for use in computational text analysis. This comes in the place of scraping the published `html` (see the [Scrape-ORACC](https://github.com/niekveldhuis/Digital-Assyriology/tree/master/Scrape-Oracc) repo). The JSON files contain all the transliteration and lemmatization data of an ORACC project (metadata are made available in a separate `.json` file). For an introduction to the various ORACC JSON files see the [ORACC Open Data](http://oracc.org/doc/opendata) page.
#
# The resulting data file may include various elements of the ORACC data structure. The current code will output a file with the following fields:
#
# * id_text
# * lemma (listing all the lemmas of that text in sequence)
#
# The selection and arrangement of fields may be adjusted with standard `Pandas` functions.
#
# ## Notes
# The current version of the script works with the `ijson` library. Documentation for [ijson](https://www.dataquest.io/blog/python-json-tutorial/), unfortunately, is extremely brief. The notebook has been tested, using a list of 106 P, Q, X numbers (in `ob_lists_wood.txt`). Downloading the `.json` files from the ORACC server takes between 30 and 45 seconds. The rest of the script is reasonably fast. With larger lists of text IDs the script will obviously take longer.
#
# This notebook is written for **Python 3.5** with **Pandas 0.19** and **ijson 2.3**.
#
# The notebook was originally written for the [Phylogenetics](https://github.com/ErinBecker/digital-humanities-phylogenetics) project with Erin Becker of [Data Carpentry](http://www.datacarpentry.org). The particular data selection and data manipulation performed in this notebook are adapted for use in the word2vec project. It should be fairly easy to adapt the notebook to the purposes of any other project that wishes to use [ORACC](http://oracc.org) data.
#
# ## Licensing
# This notebook may be downloaded, used and adapted without any restrictions.

# %%
import pandas as pd   
import ijson
import urllib.request
import re
import tqdm
import numpy as np

# %% [markdown]
# # Input List of Text IDs or a project abbreviation
# Identify a list of text IDs (P, Q, and X numbers) in the directory `input`. The IDs are six-digit P, Q, or X numbers preceded by a project abbreviation in the format 'PROJECT/P######' or 'PROJECT/SUBPROJECT/Q######'. For example:
# * dcclt/P117395
# * etcsri/Q001203
# * rinap/rinap1/Q003421
#
# The list should be created with a flat text editor such as Textedit or Emacs, and the filename should end in `.txt`.
#
# Alternatively, one may enter the name (abbreviation) of a project or sub-project in [ORACC](http://oracc.org) and pull all the lemmatized data from that project. Note that the script will not automatically pull data from subprojects, they have to be requested separately. Examples:
# * saao/saa01
# * aemw/amarna
# * rimanum

# %%
name = input('Filename or project abbreviation: ')
# Out:
# Filename or project abbreviation: dcclt/nineveh

# %%
if name[-4:] == '.txt':
    textids = 'text_ids/' + name
    with open(textids, 'r') as f:
        pqxnos = f.readlines()
    pqxnos = [x.strip() for x in pqxnos]
    files = [x[:-7] + 'corpusjson/' + x[-7:] + '.json' for x in pqxnos]
    pqxnos = [x[-7:] for x in pqxnos]
    pqxnos[:5], files[:5]
else:
    files = []
    json = '/metadata.json'
    url = 'http://oracc.museum.upenn.edu/' + name + json
    try:
        d = urllib.request.urlopen(url)
        parser = ijson.parse(d)
        for prefix, event, value in parser:
            #print(prefix)
            if prefix == 'formats.lem.item':   # get only lemmatized texts
                files.append(name + '/corpusjson/' + value + '.json')
    except:
        print(url + ' not available')

# %% [markdown]
# # Parse
# The function `oraccjsonparser()` takes one argument (the **url** of the `.json` file). It looks for the prefix `textid` to retrieve the six-digit P, Q, or X number of the text artifact. Parsing the file sequentially the code looks for the places where a line starts (`'.type' = 'line-start'`) and where a word starts (`'.node' = 'l'`, where `l` is for "lemma"). At each level the code will retrieve the relevant data and create a list where each entry is a dictionary that represents a single word.
#
# Words not only include lemmatized words, but also unlemmatized and unlemmatizable words (such as breaks).
#
# The dictionary includes the keys `id_line` and `id_word` that allow the user to reassemble words and lines in order.

# %%
def oraccjsonparser(url):
    d = urllib.request.urlopen(url)
    parser = ijson.parse(d)
    word_l = []
    word_d = {}
    line_start = False
    word_start = False
    nonx = False
    for prefix, event, value in parser:
        if prefix == 'textid':
            id_text = value
#            print("parsing " + value)
        if prefix.endswith('.type'):
            if value == 'line-start':
                line_start = True
            else:
                line_start = False
        if line_start:
            if prefix.endswith('.ref') and not word_start:
                id_line = value # id_line is a reference number for a line
                                # that includes the id_text (e.g. P123456.49)
            if prefix.endswith('.label'):
                label = value   # label is a human-readable line number of the format
                                # o ii 24' (obverse column 2 line 24')
        if prefix.endswith('node'):
            if value == 'l':
                #print(prefix)
                word_start = True
                if not word_d == {}:
                    word_l.append(word_d) # append the previous word to the list
                word_d = {}               # and start a new dictionary
                #word_d['id_text'] = id_text # provide each word with appropriate 
                #word_d['id_line'] = id_line # text and line-ID
                word_d['label'] = label     # and the line label.
            else:
                word_start = False
        if word_start:
            if prefix.endswith('cdl.item.ref') or prefix.endswith('choices.item.ref'):
                #print(prefix), print(value)
                word_d['id_word'] = value
                id_elements = value.split('.')
                word_d['id_text'] = id_elements[0]
                word_d['id_line'] = id_elements[0] + '.' + id_elements[1]
            if prefix.endswith('.sig'):
                word_d['signature'] = value
            if '.f.' in prefix:
                category = re.sub('.*\.', '', prefix) # get element after the last dot of the prefix
                word_d[category] = value # copy each element into the dictionary
        if prefix.endswith('.type'):
            if value == 'nonx':
                nonx = True
            else:
                nonx = False
        if nonx:                         # this captures so-called $-lines with information
            if prefix.endswith('.ref'):  # about number of broken lines/columns.
                id_line = value          # $-lines have their own id_line.
            if prefix.endswith('.strict'):
                if value == '1':           # select only 'strict' $ lines
                    if not word_d == {}:
                        word_l.append(word_d)
                    word_d = {}
                    word_d['id_line'] = id_line
                    word_d['id_text'] = id_text
                else:
                    nonx = False
            if prefix.endswith('.extent'): # capture the three elements of strict $ lines
                word_d['extent'] = value   # namely extent, scope, and state.
            if prefix.endswith('.scope'):
                word_d['scope'] = value
            if prefix.endswith('.state'):
                word_d['state'] = value

    word_l.append(word_d)  # make sure that the last word is captured, too.
    return(word_l) # return a list of dictionaries, where each entry (dictionary) in
                   # the list represents a word.

# %% [markdown]
# # Call the Parser Function for Each Textid

# %%
url_prefix = "http://oracc.museum.upenn.edu/"
word_l = []
for id_text in tqdm.tqdm(files):   # tqdm creates a progress bar
    try:
        url = url_prefix + id_text
        word_l.extend(oraccjsonparser(url))
    except:
        print(url + ' not available')
# Out:
# 100%|██████████| 584/584 [06:12<00:00,  2.53it/s]

# %% [markdown]
# # Transform the Data into a DataFrame

# %%
words = pd.DataFrame(word_l)
words.head()
#words.loc[words['id_text'] == 'P357082']
# Out:
#   base   cf cont epos     extent form   gw    id_line  id_text      id_word  \
# 0  NaN  NaN  NaN  NaN  beginning  NaN  NaN  P237006.4  P237006          NaN
# 1  NaN  NaN  NaN  NaN        NaN    x  NaN  P237006.5  P237006  P237006.5.2
# 2  NaN  NaN  NaN  NaN       rest  NaN  NaN  P237006.6  P237006          NaN
# 3  NaN  NaN  NaN  NaN  beginning  NaN  NaN  P237006.8  P237006          NaN
# 4  NaN  NaN  NaN  NaN        NaN  TIR  NaN  P237006.9  P237006  P237006.9.2
#
#       label lang morph norm norm0  pos   scope sense signature    state
# 0       NaN  NaN   NaN  NaN   NaN  NaN  column   NaN       NaN  missing
# 1   o i' 1'  sux   NaN  NaN   NaN  NaN     NaN   NaN       NaN      NaN
# 2       NaN  NaN   NaN  NaN   NaN  NaN  column   NaN       NaN  missing
# 3       NaN  NaN   NaN  NaN   NaN  NaN  column   NaN       NaN  missing
# 4  o ii' 1'  sux   NaN  NaN   NaN  NaN     NaN   NaN       NaN      NaN

# %% [markdown]
# # Remove Spaces and Commas from Guide Word and Sence
# Spaces in Guide Word and Sense may cause trouble in computational methods in tokenization, or when saved in Comma Separated Values format. All spaces and commas are replaced by hyphens or nothing, respectively.

# %%
words = words.fillna('') # first replace Missing Values by empty string
words['sense'] = [x.replace(' ', '-') for x in words['sense']]
words['sense'] = [x.replace(',', '') for x in words['sense']]
words['gw'] = [x.replace(' ', '-') for x in words['gw']]
words['gw'] = [x.replace(',', '') for x in words['gw']]

# %% [markdown]
# The columns in the resulting DataFrame correspond to the elements of a full [ORACC](http://oracc.org) signature, plus information about text, line, and word ids:
# * base (Sumerian only)
# * cf (Citation Form)
# * cont (continuation of the base; Sumerian only)
# * epos (Effective Part of Speech)
# * form (transliteration, omitting all flags such as indication of breakage)
# * gw (Guide Word: main or first translation in standard dictionary)
# * id_line (a line ID that begins with the six-digit P, Q, or X number of the text)
# * id_text (six-digit P, Q, or X number)
# * id_word (word ID that begins with the ID number of the line)
# * label (traditional line number in the form o ii 2' (obverse column 2 line 2'), etc.)
# * lang (language code, including sux, sux-x-emegir, sux-x-emesal, akk, akk-x-stdbab, etc)
# * morph (Morphology; Sumerian only)
# * norm (Normalization: Akkadian)
# * norm0 (Normalization: Sumerian)
# * pos (Part of Speech)
# * sense (contextual meaning)
# * signature (full ORACC signature)
#
# Not all data elements (columns) are available for all words. Sumerian words never have a `norm`, Akkadian words do not have `norm0`, `base`, `cont`, or `morph`. Most data elements are only present when the word is lemmatized; only `lang`, `form`, `pos`, `id_word`, `id_line`, and `id_text` should always be there. An unlemmatized word has `pos` 'X' (for unknown). Broken words have `pos` 'u' (for 'unlemmatizable).

# %% [markdown]
# # Manipulate
# The columns may be manipulated with standard Pandas methods to create the desired output. By way of example, the following code will create a column `lemma` with the format **cf[gw]pos** (for instance **lugal[king]N**). For words that have no lemmatization `lemma` equals `form`. Only Sumerian words are allowed (and thus `lang` can be omitted) and in addition to the column `lemma` the column `base` is preserved; words that have no lemmatization take `form` as their base. Words and bases are concatenated to lines.

# %% [markdown]
# ## Remove  non-Akkadian words

# %%
lang = ['akk', ''] # note that 'lang' is empty in entries that indicate damage
words = words.loc[words['lang'].str[:3].isin(lang)].reset_index()

# %% [markdown]
# ## Create Lemma Column and Adjust Base

# %%
words['lemma'] = words['cf'] # first element of lemma is the citation form
words['lemma'] = [words['lemma'][i] + '[' + words['gw'][i] + ']' + words['pos'][i] 
                  if not words['lemma'][i] == '' 
                  else words['form'][i] +'[NA]NA' for i in range(len(words))]
words['lemma'] = [lemma if not lemma == '[NA]NA' else '' for lemma in words['lemma'] ]
#words['base'] = [words['base'][i] if not words['base'][i] == '' 
#                 or words['label'][i] == '' else words['form'][i] 
#                 for i in range(len(words))]
lemmas = words[['lemma', 'id_text', 'id_line', 'id_word', 'label']]#, 'extent', 'scope']]
#lemmas = words[['lemma', 'base', 'id_text', 'id_line', 'id_word', 'label', 'extent', 'scope']]
lemmas.head()
# Out:
#   lemma  id_text     id_line id_word label
# 0        P237006   P237006.4
# 1        P237006   P237006.6
# 2        P237006   P237006.8
# 3        P237006  P237006.14
# 4        P237006  P237006.16

# %% [markdown]
# ## Group by Line

# %%
lines = words.groupby([words['id_line'], words['label']]).agg({
        'lemma': ' '.join,
        #'base': ' '.join,
        #'extent': ''.join, 
        #'scope': ''.join
    }).reset_index()

# %%
df = lines[['id_line', 'label', 'lemma']] #, 'base', 'extent', 'scope']]

# %%
df['id_text'] = df['id_line'].str[:7] # id_text was lost in the grouping above and is recreated
df['line'] = [re.sub('.+\.', '', line) for line in df['id_line']] #create a line number for sorting
df['line'] = [x.replace('l', '') for x in df['line']]
df
# Out:
#            id_line  label                                              lemma  \
# 0       P237006.14
# 1       P237006.16
# 2       P237006.25
# 3       P237006.27
# 4       P237006.37
# 5        P237006.4
# 6        P237006.6
# 7        P237006.8
# 8       P237064.13
# 9        P237064.3
# 10      P237218.10
# 11      P237218.16
# 12      P237218.21
# 13       P237218.3
# 14      P237218.30
# 15       P237218.7
# 16       P237218.8
# 17     P237230.104
# 18     P237230.144
# 19     P237230.152
# 20     P237230.162
# 21     P237230.168
# 22      P237230.17
# 23     P237230.177
# 24     P237230.189
# 25     P237230.193
# 26     P237230.194
# 27     P237230.195
# 28      P237230.35
# 29       P237230.4
# ...            ...    ...                                                ...
# 23215   P424642.14
# 23216   P424642.15   r 1'  x[NA]NA Sipadzid-anak[True-Shepherd-of-An]CN x...
# 23217   P424642.16
# 23218   P424642.17   r 2'           kakkabu[star]N šanû[(an)other]AJ x[NA]NA
# 23219   P424642.18   r 3'           kakkabu[star]N ahû[outside(r)]AJ x[NA]NA
# 23220   P424642.19   r 4'           kakkabu[star]N nakaru[strange]AJ x[NA]NA
# 23221   P424642.20
# 23222    P424642.3    o 1                                            x[NA]NA
# 23223    P424642.4    o 2                                            x[NA]NA
# 23224    P424642.5    o 3                                            x[NA]NA
# 23225    P424642.6
# 23226    P424642.7   o 4'                                            x[NA]NA
# 23227    P424642.8   o 5'                                            x[NA]NA
# 23228    P424642.9   o 6'                                            x[NA]NA
# 23229   P452527.10   o 8'                                    x[NA]NA x[NA]NA
# 23230   P452527.11   o 9'                                    x[NA]NA x[NA]NA
# 23231   P452527.12  o 10'                                    x[NA]NA x[NA]NA
# 23232   P452527.13  o 11'                                    x[NA]NA x[NA]NA
# 23233   P452527.14  o 12'                                    x[NA]NA x[NA]NA
# 23234   P452527.15  o 13'                                    x[NA]NA x[NA]NA
# 23235   P452527.16  o 14'                                    x[NA]NA x[NA]NA
# 23236   P452527.17  o 15'                                    x[NA]NA x[NA]NA
# 23237    P452527.2
# 23238    P452527.3   o 1'                                    x[NA]NA x[NA]NA
# 23239    P452527.4   o 2'                                    x[NA]NA x[NA]NA
# 23240    P452527.5   o 3'                                    x[NA]NA x[NA]NA
# 23241    P452527.6   o 4'                                    x[NA]NA x[NA]NA
# 23242    P452527.7   o 5'                                    x[NA]NA x[NA]NA
# 23243    P452527.8   o 6'                                    x[NA]NA x[NA]NA
# 23244    P452527.9   o 7'                                    x[NA]NA x[NA]NA
#
#        id_text line
# 0      P237006   14
# 1      P237006   16
# 2      P237006   25
# 3      P237006   27
# 4      P237006   37
# 5      P237006    4
# 6      P237006    6
# 7      P237006    8
# 8      P237064   13
# 9      P237064    3
# 10     P237218   10
# 11     P237218   16
# 12     P237218   21
# 13     P237218    3
# 14     P237218   30
# 15     P237218    7
# 16     P237218    8
# 17     P237230  104
# 18     P237230  144
# 19     P237230  152
# 20     P237230  162
# 21     P237230  168
# 22     P237230   17
# 23     P237230  177
# 24     P237230  189
# 25     P237230  193
# 26     P237230  194
# 27     P237230  195
# 28     P237230   35
# 29     P237230    4
# ...        ...  ...
# 23215  P424642   14
# 23216  P424642   15
# 23217  P424642   16
# 23218  P424642   17
# 23219  P424642   18
# 23220  P424642   19
# 23221  P424642   20
# 23222  P424642    3
# 23223  P424642    4
# 23224  P424642    5
# 23225  P424642    6
# 23226  P424642    7
# 23227  P424642    8
# 23228  P424642    9
# 23229  P452527   10
# 23230  P452527   11
# 23231  P452527   12
# 23232  P452527   13
# 23233  P452527   14
# 23234  P452527   15
# 23235  P452527   16
# 23236  P452527   17
# 23237  P452527    2
# 23238  P452527    3
# 23239  P452527    4
# 23240  P452527    5
# 23241  P452527    6
# 23242  P452527    7
# 23243  P452527    8
# 23244  P452527    9
#
# [23245 rows x 5 columns]

# %%
df['line'] = [int(x) for x in df['line']]
df = df.sort_values(['id_text', 'line']).reset_index(drop=True)
df.head(100)
# Out:
#         id_line     label                                     lemma  id_text  \
# 0     P237006.4                                                      P237006
# 1     P237006.6                                                      P237006
# 2     P237006.8                                                      P237006
# 3    P237006.14                                                      P237006
# 4    P237006.16                                                      P237006
# 5    P237006.25                                                      P237006
# 6    P237006.27                                                      P237006
# 7    P237006.37                                                      P237006
# 8     P237064.3                                                      P237064
# 9    P237064.13                                                      P237064
# 10    P237218.3                                                      P237218
# 11    P237218.7                                                      P237218
# 12    P237218.8                                                      P237218
# 13   P237218.10                                                      P237218
# 14   P237218.16                                                      P237218
# 15   P237218.21                                                      P237218
# 16   P237218.30                                                      P237218
# 17    P237230.4                                                      P237230
# 18   P237230.17                                                      P237230
# 19   P237230.35                                                      P237230
# 20   P237230.54                                                      P237230
# 21   P237230.74                                                      P237230
# 22  P237230.104                                                      P237230
# 23  P237230.144                                                      P237230
# 24  P237230.152                                                      P237230
# 25  P237230.162                                                      P237230
# 26  P237230.168                                                      P237230
# 27  P237230.177                                                      P237230
# 28  P237230.189                                                      P237230
# 29  P237230.193                                                      P237230
# ..          ...       ...                                       ...      ...
# 70   P237770.30  o i' 23'                      rāṭu[water-channel]N  P237770
# 71   P237770.31  o i' 24'                          qalqallu[grill]N  P237770
# 72   P237770.32  o i' 25'                           maqlû[burning]N  P237770
# 73   P237770.35     r i 1                qalû[oven-(for-roasting)]N  P237770
# 74   P237770.36     r i 2              kiškattû[(industrial)-kiln]N  P237770
# 75   P237770.37     r i 3                               ṭīdu[clay]N  P237770
# 76   P237770.38    r i 3a                               ṭīdu[clay]N  P237770
# 77   P237770.39     r i 4                               ṭīdu[clay]N  P237770
# 78   P237770.40    r i 4a                               ṭīdu[clay]N  P237770
# 79   P237770.41     r i 5              nappaltu[(building)-rubble]N  P237770
# 80   P237770.42     r i 6              nappaltu[(building)-rubble]N  P237770
# 81   P237770.43     r i 7  ṭīdu[clay]N nappaltu[(building)-rubble]N  P237770
# 82   P237770.44     r i 8                      hutūlu[(an-object)]N  P237770
# 83   P237770.45     r i 9                                ṭēru[mud]N  P237770
# 84   P237770.46    r i 10                              ṭerītu[mud]N  P237770
# 85   P237770.47    r i 11                           sāʾu[(a-tree)]N  P237770
# 86   P237770.48    r i 12                            bīšu[bad-one]N  P237770
# 87   P237770.49   r i 12a                          daʾmu[dark-one]N  P237770
# 88   P237770.50    r i 13                          daʾmu[dark-one]N  P237770
# 89   P237770.51   r i 13a               kalû[yellow-mineral-paste]N  P237770
# 90   P237770.52    r i 14                         wašṭu[stiff-one]N  P237770
# 91   P237770.53    r i 15                        isikku[hard-one?]N  P237770
# 92   P237770.54    r i 16                        dannu[strong-one]N  P237770
# 93   P237770.55    r i 17                         kuššikku[a-clay]N  P237770
# 94   P237770.56    r i 18                         kuššikku[a-clay]N  P237770
# 95   P237770.57    r i 19                             im-na-x[NA]NA  P237770
# 96   P237770.58    r i 20                                 x-x[NA]NA  P237770
# 97   P237770.59    r i 21                                 x-x[NA]NA  P237770
# 98   P237770.60                                                      P237770
# 99   P237770.62    r ii 1                                   x[NA]NA  P237770
#
#     line
# 0      4
# 1      6
# 2      8
# 3     14
# 4     16
# 5     25
# 6     27
# 7     37
# 8      3
# 9     13
# 10     3
# 11     7
# 12     8
# 13    10
# 14    16
# 15    21
# 16    30
# 17     4
# 18    17
# 19    35
# 20    54
# 21    74
# 22   104
# 23   144
# 24   152
# 25   162
# 26   168
# 27   177
# 28   189
# 29   193
# ..   ...
# 70    30
# 71    31
# 72    32
# 73    35
# 74    36
# 75    37
# 76    38
# 77    39
# 78    40
# 79    41
# 80    42
# 81    43
# 82    44
# 83    45
# 84    46
# 85    47
# 86    48
# 87    49
# 88    50
# 89    51
# 90    52
# 91    53
# 92    54
# 93    55
# 94    56
# 95    57
# 96    58
# 97    59
# 98    60
# 99    62
#
# [100 rows x 5 columns]

# %%
df = df.loc[np.where(df['lemma'] != '')] # kick out rows with empty lemma field
df
# Out:
#           id_line      label  \
# 33      P237713.5    o i' 1'
# 34      P237713.6    o i' 2'
# 35      P237713.7    o i' 3'
# 36      P237713.8    o i' 4'
# 37      P237713.9    o i' 5'
# 38     P237713.10    o i' 6'
# 39     P237713.11    o i' 7'
# 40     P237713.12    o i' 8'
# 41     P237713.13    o i' 9'
# 42     P237713.14   o i' 10'
# 45      P237770.5    o i' 1'
# 46      P237770.6    o i' 2'
# 47      P237770.7    o i' 3'
# 48      P237770.8    o i' 4'
# 49      P237770.9    o i' 5'
# 50     P237770.10    o i' 6'
# 51     P237770.11    o i' 7'
# 52     P237770.12    o i' 8'
# 53     P237770.13   o i' 8a'
# 54     P237770.14    o i' 9'
# 55     P237770.15   o i' 10'
# 56     P237770.16   o i' 11'
# 57     P237770.17   o i' 12'
# 58     P237770.18   o i' 13'
# 59     P237770.19   o i' 14'
# 60     P237770.20   o i' 15'
# 61     P237770.21   o i' 16'
# 62     P237770.22   o i' 17'
# 63     P237770.23  o i' 17a'
# 64     P237770.24   o i' 18'
# ...           ...        ...
# 23205  P424546.27     ii' 3'
# 23207  P424546.29     ii' 4'
# 23208  P424546.30     ii' 5'
# 23209  P424546.31     ii' 6'
# 23212   P424642.3        o 1
# 23213   P424642.4        o 2
# 23214   P424642.5        o 3
# 23216   P424642.7       o 4'
# 23217   P424642.8       o 5'
# 23218   P424642.9       o 6'
# 23220  P424642.11       o 7'
# 23223  P424642.15       r 1'
# 23225  P424642.17       r 2'
# 23226  P424642.18       r 3'
# 23227  P424642.19       r 4'
# 23230   P452527.3       o 1'
# 23231   P452527.4       o 2'
# 23232   P452527.5       o 3'
# 23233   P452527.6       o 4'
# 23234   P452527.7       o 5'
# 23235   P452527.8       o 6'
# 23236   P452527.9       o 7'
# 23237  P452527.10       o 8'
# 23238  P452527.11       o 9'
# 23239  P452527.12      o 10'
# 23240  P452527.13      o 11'
# 23241  P452527.14      o 12'
# 23242  P452527.15      o 13'
# 23243  P452527.16      o 14'
# 23244  P452527.17      o 15'
#
#                                                    lemma  id_text  line
# 33                                         karašu[leek]N  P237713     5
# 34                                    purussû[decision]N  P237713     6
# 35                                            šamû[sky]N  P237713     7
# 36                             diktu[(a-type-of-flour)]N  P237713     8
# 37                            zahannu[(a-garden-plant)]N  P237713     9
# 38                                        edinu[desert]N  P237713    10
# 39                                           ṣēru[back]N  P237713    11
# 40                                               x[NA]NA  P237713    12
# 41                                               x[NA]NA  P237713    13
# 42                                               x[NA]NA  P237713    14
# 45                                             x-x[NA]NA  P237770     5
# 46                                               x[NA]NA  P237770     6
# 47                                               x[NA]NA  P237770     7
# 48                                  adūgu[oven]N x[NA]NA  P237770     8
# 49                                 tinūru[oven]N x[NA]NA  P237770     9
# 50                      ṣāhu[oven-(for-oil-processing)]N  P237770    10
# 51                                kannu[(vessel-)stand]N  P237770    11
# 52                                kannu[(vessel-)stand]N  P237770    12
# 53                                kannu[(vessel-)stand]N  P237770    13
# 54                                kannu[(vessel-)stand]N  P237770    14
# 55                                       maqlû[burning]N  P237770    15
# 56                            qalû[oven-(for-roasting)]N  P237770    16
# 57                                laptu[roasted-barley]N  P237770    17
# 58                                           kūru[kiln]N  P237770    18
# 59                                    nappašu[air-hole]N  P237770    19
# 60                                           kūru[kiln]N  P237770    20
# 61                                       idrānu[potash]N  P237770    21
# 62                                       haṣbu[pottery]N  P237770    22
# 63                                  išhilṣu[(pot)sherd]N  P237770    23
# 64                                  išhilṣu[(pot)sherd]N  P237770    24
# ...                                                  ...      ...   ...
# 23205                                            x[NA]NA  P424546    27
# 23207                                            x[NA]NA  P424546    29
# 23208                                            x[NA]NA  P424546    30
# 23209                                            x[NA]NA  P424546    31
# 23212                                            x[NA]NA  P424642     3
# 23213                                            x[NA]NA  P424642     4
# 23214                                            x[NA]NA  P424642     5
# 23216                                            x[NA]NA  P424642     7
# 23217                                            x[NA]NA  P424642     8
# 23218                                            x[NA]NA  P424642     9
# 23220                                            x[NA]NA  P424642    11
# 23223  x[NA]NA Sipadzid-anak[True-Shepherd-of-An]CN x...  P424642    15
# 23225           kakkabu[star]N šanû[(an)other]AJ x[NA]NA  P424642    17
# 23226           kakkabu[star]N ahû[outside(r)]AJ x[NA]NA  P424642    18
# 23227           kakkabu[star]N nakaru[strange]AJ x[NA]NA  P424642    19
# 23230                                    x[NA]NA x[NA]NA  P452527     3
# 23231                                    x[NA]NA x[NA]NA  P452527     4
# 23232                                    x[NA]NA x[NA]NA  P452527     5
# 23233                                    x[NA]NA x[NA]NA  P452527     6
# 23234                                    x[NA]NA x[NA]NA  P452527     7
# 23235                                    x[NA]NA x[NA]NA  P452527     8
# 23236                                    x[NA]NA x[NA]NA  P452527     9
# 23237                                    x[NA]NA x[NA]NA  P452527    10
# 23238                                    x[NA]NA x[NA]NA  P452527    11
# 23239                                    x[NA]NA x[NA]NA  P452527    12
# 23240                                    x[NA]NA x[NA]NA  P452527    13
# 23241                                    x[NA]NA x[NA]NA  P452527    14
# 23242                                    x[NA]NA x[NA]NA  P452527    15
# 23243                                    x[NA]NA x[NA]NA  P452527    16
# 23244                                    x[NA]NA x[NA]NA  P452527    17
#
# [19638 rows x 5 columns]

# %%
grouped = df['lemma'].groupby(df['id_text']).apply(' '.join).reset_index()
by_text_df = pd.DataFrame(grouped)
by_text_df = by_text_df.set_index('id_text')
by_text_df
# Out:
#                                                      lemma
# id_text
# P237713  karašu[leek]N purussû[decision]N šamû[sky]N di...
# P237770  x-x[NA]NA x[NA]NA x[NA]NA adūgu[oven]N x[NA]NA...
# P238140  x[NA]NA x[NA]NA x[NA]NA alû[(a-kind-of-drum)]N...
# P238324  makkūru[property]N makkūru[property]N šarru[ki...
# P238446  abu[father]N ummu[mother]N bēlu[lord]N bēltu[l...
# P238817  pagūmu[(harness-strap)?]N mašku[skin]N karru[k...
# P239302  kaṣṣidakku[miller]N ṭeʾīnu[grinder]N nukaribbu...
# P239552  x[NA]NA x-x-tum[NA]NA x[NA]NA qaqqadu[head]N x...
# P254706  x[NA]NA ana[to]PRP x[NA]NA ana[to]PRP x[NA]NA ...
# P274783  PEŠ[NA]NA GAL[NA]NA {m}{d}PA-x[NA]NA PEŠ[NA]NA...
# P282465  DAM[NA]NA AN.NA-KE₄[NA]NA DAM[NA]NA BAN₃.DA[NA...
# P286011  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]N...
# P286023  x-x[NA]NA x-x[NA]NA MUNUS[NA]NA x[NA]NA x[NA]N...
# P286029  x-x[NA]NA x-x[NA]NA x-x-tu[NA]NA x-x-lu[NA]NA ...
# P286031  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]N...
# P289805  ašlu[rush]N lēʾu[board]N mašṭaru[inscription]N...
# P345974  x-x[NA]NA x[NA]NA x-x-KI[NA]NA x-x[NA]NA x-nu-...
# P345979  x[NA]NA pa-x-x[NA]NA x-x[NA]NA ZA-ra-x[NA]NA x...
# P345982  šapāṭu[give-judgement]V diānu[judge]V gamāru[b...
# P345989  x[NA]NA x-x[NA]NA x[NA]NA x-BU[NA]NA x[NA]NA x...
# P345990  x-x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA mārt...
# P345992  ba-a-ru[NA]NA zi-it-tu[NA]NA ba-a-ru[NA]NA is-...
# P346000  yašibu[battering-ram]N yašibu[battering-ram]N ...
# P346001  ša[of]DET lišānu[tongue]N x[NA]NA lā[not]MOD i...
# P346005  x[NA]NA x-x[NA]NA x[NA]NA x-ul-la-x[NA]NA x[NA...
# P346007  e-lum[NA]NA BIT-x[NA]NA šitpuṣu[quarrelsome-on...
# P346013  x[NA]NA x-x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA...
# P346023  x[NA]NA šerru[(young)-child]N x[NA]NA ṣehru[sm...
# P346041  x-x[NA]NA hurāṣu[gold]N x-x[NA]NA hullu[neck-r...
# P346052  x[NA]NA x-x-x[NA]NA x[NA]NA šikkūtu[string-of-...
# ...                                                    ...
# P423615  x[NA]NA ša[of]DET x[NA]NA x[NA]NA ša[of]DET x[...
# P423616  x-du-u[NA]NA ṣu-un-nu[NA]NA x-du-u[NA]NA uznu[...
# P423617  x-x[NA]NA mušlahhūtu[art-of-the-snake-charmer]...
# P423618  x[NA]NA ša[of]DET nāru[river]N x[NA]NA ša[of]D...
# P423619  x[NA]NA x[NA]NA šalāš[three]NU DIŠ[NA]NA šūši[...
# P423620  šiltāhu[arrow]N mulmullu[arrow]N mulmullu[arro...
# P423622  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]N...
# P423623  takaltu[bag]N patru[dagger]N takaltu[bag]N qan...
# P423625    x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA
# P423626  x[NA]NA nabnītu[creation]N x-A[NA]NA x[NA]NA A...
# P423627  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]N...
# P423630  e-re-x[NA]NA e-pi-x[NA]NA ta-ha-zu[NA]NA it-qu...
# P423631  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA ša[of]...
# P423632  gurguššû[(a-big-offering-vessel)]N dunsānu[(a-...
# P423633  x[NA]NA x[NA]NA x-ru[NA]NA x-x-ru[NA]NA x[NA]N...
# P423634  x-x[NA]NA x-u[NA]NA x-u₂[NA]NA x-qu[NA]NA x-x-...
# P423635  x-x[NA]NA x-x[NA]NA x-x[NA]NA x-tum[NA]NA x-tu...
# P423636  x[NA]NA x[NA]NA x[NA]NA x[NA]NA bitrû[be(come)...
# P423640  x[NA]NA x[NA]NA x[NA]NA x[NA]NA nadû[(stele)?]...
# P423641  hassū[lettuce]N guzāzu[kind-of-lettuce?]N murā...
# P423642  ašlu[rush]N urbatu[rush]N elpetu[alfalfa-grass...
# P423643  lardu[(a-grass)]N lardu[(a-grass)]N lardu[(a-g...
# P423644  šammu[plant(s)]N dēšû[abundant-one]N dēšû[abun...
# P423648  x-ah-mu[NA]NA x-hi-mu[NA]NA x-bu-u₂[NA]NA baʾā...
# P423649  mi-x[NA]NA hulamīsu[(a-tree)]N daprānu[juniper...
# P423650  x-x-x[NA]NA še-lu-u₂[NA]NA še-lu-u₂[NA]NA šelû...
# P423653  lahtanu[(a-beer-vat)]N x[NA]NA hubūru[(a-beer-...
# P424546  x-tum[NA]NA x[NA]NA x[NA]NA x-ha-ru[NA]NA nadā...
# P424642  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]N...
# P452527  x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]NA x[NA]N...
#
# [559 rows x 1 columns]

# %% [markdown]
# ## Save in CSV Format

# %%
if name[-4:] == '.txt': # list of P/Q/X numbers in .txt file
    filename = name[:-4]
else:                  # full project
    filename = name.replace('/', '_')
with open('output/' + filename + '.csv', 'w') as w:
    by_text_df.to_csv(w, encoding='utf8')
